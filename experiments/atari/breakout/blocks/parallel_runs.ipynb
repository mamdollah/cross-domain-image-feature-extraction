# %% [markdown]
# # Importing Libraries

# %%
import datetime
import multiprocessing
import random
import time

import torch
import wandb
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CallbackList, EvalCallback
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack, VecTransposeImage
from wandb.integration.sb3 import WandbCallback
from feature_extraction.callbacks.wandb_on_training_end_callback import WandbOnTrainingEndCallback
from feature_extraction.feature_extractors.resnet.block_feature_extractor import BlockFeatureExtractor
from feature_extraction.wrappers.vec_feature_extractor import VecFeatureExtractor
from utils import linear_schedule
from collections import OrderedDict

from torchvision.models import ResNet50_Weights, resnet50
# Out:
# 2024-04-01 20:14:03.555425: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-01 20:14:03.574324: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-01 20:14:03.574343: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-01 20:14:03.574860: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-01 20:14:03.578096: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-01 20:14:03.958281: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/mamdi/PycharmProjects/Global-Feature-Extraction/venv/lib/python3.10/site-packages/transformers/utils/generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(

# %% [markdown]
# # Method for creating a new configuration

# %%
def create_config(project_name, run_name):
    """
    Creates a new configuration as an OrderedDict with a specified project and run name,
    and sets the training_seed and evaluation_seed to random integers,
    while using a predefined set of default settings for the rest.

    Parameters:
    - project_name (str): Name of the project.
    - run_name (str): Name of the run.

    Returns:
    - OrderedDict: A new configuration dictionary with the specified project and run names,
                   random seeds, and default settings for other parameters.
    """
    training_seed = random.randint(0, 9999) # Should later on be same for all experiments to ensure comparability
    evaluation_seed = random.randint(0, 9999) # Should later on be same for all experiments to ensure comparability

    default_config = OrderedDict([
        # Environment settings
        ('project_name', project_name),
        ('run_name', run_name),
        ('env_id', "BreakoutNoFrameskip-v4"),
        ('n_envs', 8),
        ('env_wrapper', ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
        ('frame_stack', 4),
        ('training_seed', 12),
        ('evaluation_seed', 14),
        
        # Algorithm and policy settings
        ('algo', 'PPO'),
        ('policy', 'MlpPolicy'),
        
        # Training hyperparameters
        ('batch_size', 256),
        ('n_steps', 128),
        ('n_epochs', 4),
        ('n_timesteps', 10_000_000),
        ('learning_rate', 0.00025),
        ('learning_rate_schedule', 'linear'),
        ('clip_range', 0.1),
        ('clip_range_schedule', 'linear'),
        ('ent_coef', 0.01),
        ('vf_coef', 0.5),
        ('normalize_advantage', False),
        
        # Evaluation and logging settings
        ('n_eval_episodes', 5),
        ('record_n_episodes', 10),
        ('n_final_eval_episodes', 25),
        ('log_frequency', 50_000),
        
        # Other settings
        ('verbose', 1)
    ])
    

    return default_config

# %% [markdown]
# # Method for running a single experiment with a configuration

# %%
def run_experiment(config):
    wandb.login()

    # Initialize the wandb run
    wandb.init(project=config['project_name'],
                     name=config['run_name'],
                     config=config, save_code=True,
                     sync_tensorboard=True)
    
    config = wandb.config
    
    log_dir = f"logs/{config.run_name}"
    #feature_extractor = StageFeatureExtractor()
    
    model = resnet50(weights=ResNet50_Weights.IMAGENET1K_V2)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("Device: ", device)
    model.to(device)
    feature_extractor = BlockFeatureExtractor(model, 1)

    # Create Evaluation Environment
    vec_eval_env = make_atari_env(config.env_id, n_envs=config.n_envs, seed=config.evaluation_seed)
    vec_eval_env = VecFrameStack(vec_eval_env, n_stack=config.frame_stack)
    vec_eval_env = VecTransposeImage(vec_eval_env)
    vec_eval_env = VecFeatureExtractor(vec_eval_env, feature_extractor)

    # Create Training Environment
    vec_train_env = make_atari_env(config.env_id, n_envs=config.n_envs, seed=config.training_seed)
    vec_train_env = VecFrameStack(vec_train_env, n_stack=config.frame_stack)
    vec_train_env = VecTransposeImage(vec_train_env)
    vec_train_env = VecFeatureExtractor(vec_train_env, feature_extractor)

    # Define the keys for PPO-specific hyperparameters
    ppo_params_keys = [
        'batch_size',
        'ent_coef',
        'n_epochs',
        'n_steps',
        'policy',
        'vf_coef',
        'normalize_advantage',
    ]

    # Filter the config dictionary to extract only the PPO hyperparameters
    ppo_hyperparams = {key: config[key] for key in ppo_params_keys if key in config}

    # Additional hyperparameters not in the initial filter that require custom handling
    learning_rate_schedule = linear_schedule(2.5e-4)
    clip_range_schedule = linear_schedule(0.1)

    # Instantiate the PPO model with the specified hyperparameters and environment
    model = PPO(
        **ppo_hyperparams,
        learning_rate=learning_rate_schedule,
        clip_range=clip_range_schedule,
        env=vec_train_env,
        verbose=1,
        tensorboard_log=f"{log_dir}",
    )

    
    
    # Save best model
    eval_callback = EvalCallback(
        eval_env=vec_eval_env,
        eval_freq=max(config.log_frequency // config.n_envs, 1),
        n_eval_episodes=config.n_eval_episodes,
        best_model_save_path=log_dir,
        log_path=log_dir,
        deterministic=True,
        render=False,
        verbose=0
    )

    # Needs to be changed, so it uses run instead of wandb
    wandb_callback = WandbCallback(
        verbose=1,
        gradient_save_freq=256,
    )

    wandb_on_training_end_callback = WandbOnTrainingEndCallback(
        model=model,
        eval_env=vec_eval_env,
        log_dir=log_dir,
        n_eval_episodes=config.n_final_eval_episodes,
        record_n_episodes=config.record_n_episodes,
    )
    callbacks = CallbackList([wandb_callback, eval_callback, wandb_on_training_end_callback])

    model.learn(
        total_timesteps=config.n_timesteps,
        callback=callbacks,
    )

    wandb.finish()

# %% [markdown]
# # Method for running multiple experiments with a configuration

# %%
def run_experiments_in_parallel(config_list):
    processes = []
    for config in config_list:
        p = multiprocessing.Process(target=run_experiment, args=(config,))
        p.start()
        processes.append(p)
        time.sleep(60) # Sleep to avoid file write conflicts

    for p in processes:
        p.join()

# %% [markdown]
# # Run experiments

# %%
configs = []
runs = ["breakout_block1"]

for run in runs:
    timestamp = datetime.datetime.now().strftime('_%Y-%m-%d_%H-%M-%S')
    
    project_name = "experiments"
    run_name = run + timestamp
    
    new_config = create_config(project_name, run_name)
    configs.append(new_config)

# Run experiments in parallel
run_experiments_in_parallel(configs)
# Out:
# wandb: Currently logged in as: adicreson (feature_extraction). Use `wandb login --relogin` to force relogin
# wandb version 0.16.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/home/mamdi/PycharmProjects/Global-Feature-Extraction/experiments/atari/breakout/blocks/wandb/run-20240401_201405-z4j2k72d</code>
# Syncing run <strong><a href='https://wandb.ai/feature_extraction/experiments/runs/z4j2k72d' target="_blank">breakout_block1_2024-04-01_20-14-05</a></strong> to <a href='https://wandb.ai/feature_extraction/experiments' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/feature_extraction/experiments' target="_blank">https://wandb.ai/feature_extraction/experiments</a>
#  View run at <a href='https://wandb.ai/feature_extraction/experiments/runs/z4j2k72d' target="_blank">https://wandb.ai/feature_extraction/experiments/runs/z4j2k72d</a>
# Device:  cuda
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Using cuda device
# Logging to logs/breakout_block1_2024-04-01_20-14-05/PPO_1
# 2024-04-01 20:14:08.564458: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-01 20:14:08.600693: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-01 20:14:08.600725: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-01 20:14:08.601385: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-01 20:14:08.606089: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-01 20:14:09.162969: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# -----------------------------
# | time/              |      |
# |    fps             | 185  |
# |    iterations      | 1    |
# |    time_elapsed    | 5    |
# |    total_timesteps | 1024 |
# -----------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 807          |
# |    ep_rew_mean          | 1.75         |
# | time/                   |              |
# |    fps                  | 221          |
# |    iterations           | 2            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0011689776 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.0672      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.308       |
# |    n_updates            | 4            |
# |    policy_gradient_loss | -0.328       |
# |    value_loss           | 0.0637       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 740           |
# |    ep_rew_mean          | 1.36          |
# | time/                   |               |
# |    fps                  | 242           |
# |    iterations           | 3             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 0.00026475667 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.0287        |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.166        |
# |    n_updates            | 8             |
# |    policy_gradient_loss | -0.18         |
# |    value_loss           | 0.0468        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 722           |
# |    ep_rew_mean          | 1.29          |
# | time/                   |               |
# |    fps                  | 236           |
# |    iterations           | 4             |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00042131974 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.0207        |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.154        |
# |    n_updates            | 12            |
# |    policy_gradient_loss | -0.156        |
# |    value_loss           | 0.0575        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 728           |
# |    ep_rew_mean          | 1.31          |
# | time/                   |               |
# |    fps                  | 235           |
# |    iterations           | 5             |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 0.00068829523 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.012         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.07         |
# |    n_updates            | 16            |
# |    policy_gradient_loss | -0.103        |
# |    value_loss           | 0.0727        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 724          |
# |    ep_rew_mean          | 1.29         |
# | time/                   |              |
# |    fps                  | 241          |
# |    iterations           | 6            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0017577079 |
# |    clip_fraction        | 0.0757       |
# |    clip_range           | 0.0999       |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00724      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0242      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0516      |
# |    value_loss           | 0.0656       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 709          |
# |    ep_rew_mean          | 1.22         |
# | time/                   |              |
# |    fps                  | 252          |
# |    iterations           | 7            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0023753983 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0999       |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00702      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00377     |
# |    n_updates            | 24           |
# |    policy_gradient_loss | -0.0161      |
# |    value_loss           | 0.067        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 707         |
# |    ep_rew_mean          | 1.21        |
# | time/                   |             |
# |    fps                  | 260         |
# |    iterations           | 8           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.002337798 |
# |    clip_fraction        | 0.0142      |
# |    clip_range           | 0.0999      |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00166     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0183      |
# |    n_updates            | 28          |
# |    policy_gradient_loss | 0.00607     |
# |    value_loss           | 0.0579      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 699          |
# |    ep_rew_mean          | 1.17         |
# | time/                   |              |
# |    fps                  | 267          |
# |    iterations           | 9            |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0018968555 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0999       |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00813      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00644     |
# |    n_updates            | 32           |
# |    policy_gradient_loss | -0.0385      |
# |    value_loss           | 0.0802       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 714          |
# |    ep_rew_mean          | 1.27         |
# | time/                   |              |
# |    fps                  | 274          |
# |    iterations           | 10           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0010211659 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0999       |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00668      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0228       |
# |    n_updates            | 36           |
# |    policy_gradient_loss | 0.00329      |
# |    value_loss           | 0.0687       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 703           |
# |    ep_rew_mean          | 1.19          |
# | time/                   |               |
# |    fps                  | 279           |
# |    iterations           | 11            |
# |    time_elapsed         | 40            |
# |    total_timesteps      | 11264         |
# | train/                  |               |
# |    approx_kl            | 0.00078339997 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.0999        |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.00432       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0218        |
# |    n_updates            | 40            |
# |    policy_gradient_loss | 0.0114        |
# |    value_loss           | 0.0632        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 696          |
# |    ep_rew_mean          | 1.15         |
# | time/                   |              |
# |    fps                  | 283          |
# |    iterations           | 12           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0007336813 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0999       |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00274     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0585       |
# |    n_updates            | 44           |
# |    policy_gradient_loss | 0.0629       |
# |    value_loss           | 0.0443       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 694           |
# |    ep_rew_mean          | 1.14          |
# | time/                   |               |
# |    fps                  | 284           |
# |    iterations           | 13            |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 13312         |
# | train/                  |               |
# |    approx_kl            | 0.00037161325 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.0999        |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.00481       |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0208       |
# |    n_updates            | 48            |
# |    policy_gradient_loss | -0.0153       |
# |    value_loss           | 0.058         |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 691         |
# |    ep_rew_mean          | 1.11        |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 14          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.002008117 |
# |    clip_fraction        | 0.0315      |
# |    clip_range           | 0.0999      |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00921     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.021       |
# |    n_updates            | 52          |
# |    policy_gradient_loss | -0.0226     |
# |    value_loss           | 0.0621      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 694          |
# |    ep_rew_mean          | 1.13         |
# | time/                   |              |
# |    fps                  | 291          |
# |    iterations           | 15           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0012228263 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0999       |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00798      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0179      |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.0396      |
# |    value_loss           | 0.0796       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 693           |
# |    ep_rew_mean          | 1.12          |
# | time/                   |               |
# |    fps                  | 293           |
# |    iterations           | 16            |
# |    time_elapsed         | 55            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.00047999644 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.0998        |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00659      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0663        |
# |    n_updates            | 60            |
# |    policy_gradient_loss | 0.0704        |
# |    value_loss           | 0.0536        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 696          |
# |    ep_rew_mean          | 1.13         |
# | time/                   |              |
# |    fps                  | 295          |
# |    iterations           | 17           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0021827728 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.0998       |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00412      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00642      |
# |    n_updates            | 64           |
# |    policy_gradient_loss | 0.00167      |
# |    value_loss           | 0.0514       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 690         |
# |    ep_rew_mean          | 1.1         |
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 18          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.004794303 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.0998      |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00349     |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0329     |
# |    n_updates            | 68          |
# |    policy_gradient_loss | -0.0719     |
# |    value_loss           | 0.0867      |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 703           |
# |    ep_rew_mean          | 1.17          |
# | time/                   |               |
# |    fps                  | 296           |
# |    iterations           | 19            |
# |    time_elapsed         | 65            |
# |    total_timesteps      | 19456         |
# | train/                  |               |
# |    approx_kl            | 0.00071734644 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.0998        |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.000445      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.046         |
# |    n_updates            | 72            |
# |    policy_gradient_loss | 0.0471        |
# |    value_loss           | 0.0618        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 699          |
# |    ep_rew_mean          | 1.15         |
# | time/                   |              |
# |    fps                  | 298          |
# |    iterations           | 20           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0031914571 |
# |    clip_fraction        | 0.0984       |
# |    clip_range           | 0.0998       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.00814      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0292      |
# |    n_updates            | 76           |
# |    policy_gradient_loss | -0.0608      |
# |    value_loss           | 0.0844       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 688          |
# |    ep_rew_mean          | 1.07         |
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 21           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 21504        |
# | train/                  |              |
# |    approx_kl            | 0.0031523188 |
# |    clip_fraction        | 0.0676       |
# |    clip_range           | 0.0998       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.00173     |
# |    learning_rate        | 0.000249     |
# |    loss                 | 0.072        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | 0.0734       |
# |    value_loss           | 0.0563       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 697          |
# |    ep_rew_mean          | 1.12         |
# | time/                   |              |
# |    fps                  | 296          |
# |    iterations           | 22           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0002893955 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0998       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.00427      |
# |    learning_rate        | 0.000249     |
# |    loss                 | 0.0124       |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.0174      |
# |    value_loss           | 0.0655       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 702          |
# |    ep_rew_mean          | 1.15         |
# | time/                   |              |
# |    fps                  | 295          |
# |    iterations           | 23           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0006127604 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0998       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.00443      |
# |    learning_rate        | 0.000249     |
# |    loss                 | -0.011       |
# |    n_updates            | 88           |
# |    policy_gradient_loss | -0.0162      |
# |    value_loss           | 0.0749       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 700          |
# |    ep_rew_mean          | 1.13         |
# | time/                   |              |
# |    fps                  | 297          |
# |    iterations           | 24           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0004948703 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0998       |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00332      |
# |    learning_rate        | 0.000249     |
# |    loss                 | 0.00702      |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.0094      |
# |    value_loss           | 0.0634       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 718         |
# |    ep_rew_mean          | 1.22        |
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 25          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.002252051 |
# |    clip_fraction        | 0.0588      |
# |    clip_range           | 0.0998      |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00611     |
# |    learning_rate        | 0.000249    |
# |    loss                 | -0.0363     |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -0.0486     |
# |    value_loss           | 0.0814      |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 721           |
# |    ep_rew_mean          | 1.26          |
# | time/                   |               |
# |    fps                  | 295           |
# |    iterations           | 26            |
# |    time_elapsed         | 90            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00083275937 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.0997        |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.00432       |
# |    learning_rate        | 0.000249      |
# |    loss                 | 0.00236       |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.013        |
# |    value_loss           | 0.0795        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 720          |
# |    ep_rew_mean          | 1.25         |
# | time/                   |              |
# |    fps                  | 296          |
# |    iterations           | 27           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 27648        |
# | train/                  |              |
# |    approx_kl            | 0.0014438669 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0997       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.00555      |
# |    learning_rate        | 0.000249     |
# |    loss                 | 0.0575       |
# |    n_updates            | 104          |
# |    policy_gradient_loss | 0.0252       |
# |    value_loss           | 0.0785       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 736           |
# |    ep_rew_mean          | 1.35          |
# | time/                   |               |
# |    fps                  | 296           |
# |    iterations           | 28            |
# |    time_elapsed         | 96            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00090715376 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.0997        |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.00113       |
# |    learning_rate        | 0.000249      |
# |    loss                 | 0.0657        |
# |    n_updates            | 108           |
# |    policy_gradient_loss | 0.04          |
# |    value_loss           | 0.0639        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 730           |
# |    ep_rew_mean          | 1.31          |
# | time/                   |               |
# |    fps                  | 296           |
# |    iterations           | 29            |
# |    time_elapsed         | 99            |
# |    total_timesteps      | 29696         |
# | train/                  |               |
# |    approx_kl            | 0.00019971153 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.0997        |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.00683       |
# |    learning_rate        | 0.000249      |
# |    loss                 | -0.035        |
# |    n_updates            | 112           |
# |    policy_gradient_loss | -0.0676       |
# |    value_loss           | 0.0888        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 740          |
# |    ep_rew_mean          | 1.35         |
# | time/                   |              |
# |    fps                  | 298          |
# |    iterations           | 30           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0005025525 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0997       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.00178      |
# |    learning_rate        | 0.000249     |
# |    loss                 | 0.0604       |
# |    n_updates            | 116          |
# |    policy_gradient_loss | 0.0461       |
# |    value_loss           | 0.0543       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 750          |
# |    ep_rew_mean          | 1.41         |
# | time/                   |              |
# |    fps                  | 299          |
# |    iterations           | 31           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 0.0011365594 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0997       |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00586      |
# |    learning_rate        | 0.000249     |
# |    loss                 | -0.0144      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0351      |
# |    value_loss           | 0.0805       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 743           |
# |    ep_rew_mean          | 1.37          |
# | time/                   |               |
# |    fps                  | 299           |
# |    iterations           | 32            |
# |    time_elapsed         | 109           |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00049559487 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.0997        |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00174      |
# |    learning_rate        | 0.000249      |
# |    loss                 | 0.105         |
# |    n_updates            | 124           |
# |    policy_gradient_loss | 0.0638        |
# |    value_loss           | 0.051         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 741           |
# |    ep_rew_mean          | 1.36          |
# | time/                   |               |
# |    fps                  | 300           |
# |    iterations           | 33            |
# |    time_elapsed         | 112           |
# |    total_timesteps      | 33792         |
# | train/                  |               |
# |    approx_kl            | 0.00062316685 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.0997        |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.00422       |
# |    learning_rate        | 0.000249      |
# |    loss                 | 0.0231        |
# |    n_updates            | 128           |
# |    policy_gradient_loss | 0.00797       |
# |    value_loss           | 0.0669        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 741           |
# |    ep_rew_mean          | 1.36          |
# | time/                   |               |
# |    fps                  | 298           |
# |    iterations           | 34            |
# |    time_elapsed         | 116           |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.00017121667 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.0997        |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.00567       |
# |    learning_rate        | 0.000249      |
# |    loss                 | -0.0709       |
# |    n_updates            | 132           |
# |    policy_gradient_loss | -0.113        |
# |    value_loss           | 0.0952        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 767          |
# |    ep_rew_mean          | 1.5          |
# | time/                   |              |
# |    fps                  | 296          |
# |    iterations           | 35           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 35840        |
# | train/                  |              |
# |    approx_kl            | 0.0007666907 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0997       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.00542      |
# |    learning_rate        | 0.000249     |
# |    loss                 | -0.0492      |
# |    n_updates            | 136          |
# |    policy_gradient_loss | -0.0763      |
# |    value_loss           | 0.0946       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 784          |
# |    ep_rew_mean          | 1.62         |
# | time/                   |              |
# |    fps                  | 296          |
# |    iterations           | 36           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0027980937 |
# |    clip_fraction        | 0.0601       |
# |    clip_range           | 0.0996       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.00501      |
# |    learning_rate        | 0.000249     |
# |    loss                 | -0.052       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.101       |
# |    value_loss           | 0.113        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 794        |
# |    ep_rew_mean          | 1.68       |
# | time/                   |            |
# |    fps                  | 293        |
# |    iterations           | 37         |
# |    time_elapsed         | 129        |
# |    total_timesteps      | 37888      |
# | train/                  |            |
# |    approx_kl            | 0.00242383 |
# |    clip_fraction        | 0.0525     |
# |    clip_range           | 0.0996     |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.00427    |
# |    learning_rate        | 0.000249   |
# |    loss                 | 0.019      |
# |    n_updates            | 144        |
# |    policy_gradient_loss | -0.0103    |
# |    value_loss           | 0.106      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 811         |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 294         |
# |    iterations           | 38          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.002207808 |
# |    clip_fraction        | 0.0554      |
# |    clip_range           | 0.0996      |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.00419     |
# |    learning_rate        | 0.000249    |
# |    loss                 | 0.0397      |
# |    n_updates            | 148         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.105       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 810          |
# |    ep_rew_mean          | 1.78         |
# | time/                   |              |
# |    fps                  | 293          |
# |    iterations           | 39           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 39936        |
# | train/                  |              |
# |    approx_kl            | 0.0006109401 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0996       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.000366     |
# |    learning_rate        | 0.000249     |
# |    loss                 | 0.0698       |
# |    n_updates            | 152          |
# |    policy_gradient_loss | 0.0521       |
# |    value_loss           | 0.0897       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 834           |
# |    ep_rew_mean          | 1.92          |
# | time/                   |               |
# |    fps                  | 293           |
# |    iterations           | 40            |
# |    time_elapsed         | 139           |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00055652956 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.0996        |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0.00466       |
# |    learning_rate        | 0.000249      |
# |    loss                 | -0.0185       |
# |    n_updates            | 156           |
# |    policy_gradient_loss | -0.0554       |
# |    value_loss           | 0.104         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 829          |
# |    ep_rew_mean          | 1.89         |
# | time/                   |              |
# |    fps                  | 294          |
# |    iterations           | 41           |
# |    time_elapsed         | 142          |
# |    total_timesteps      | 41984        |
# | train/                  |              |
# |    approx_kl            | 0.0015262042 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.0996       |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.00442      |
# |    learning_rate        | 0.000249     |
# |    loss                 | 0.0393       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | 0.019        |
# |    value_loss           | 0.102        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 831           |
# |    ep_rew_mean          | 1.9           |
# | time/                   |               |
# |    fps                  | 293           |
# |    iterations           | 42            |
# |    time_elapsed         | 146           |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00074658403 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.0996        |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | -0.00163      |
# |    learning_rate        | 0.000249      |
# |    loss                 | 0.104         |
# |    n_updates            | 164           |
# |    policy_gradient_loss | 0.0952        |
# |    value_loss           | 0.0675        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 839          |
# |    ep_rew_mean          | 1.95         |
# | time/                   |              |
# |    fps                  | 294          |
# |    iterations           | 43           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 44032        |
# | train/                  |              |
# |    approx_kl            | 0.0011214982 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0996       |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.0049       |
# |    learning_rate        | 0.000249     |
# |    loss                 | -0.0254      |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -0.0538      |
# |    value_loss           | 0.107        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 841          |
# |    ep_rew_mean          | 1.99         |
# | time/                   |              |
# |    fps                  | 293          |
# |    iterations           | 44           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0013394881 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0996       |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.00412      |
# |    learning_rate        | 0.000249     |
# |    loss                 | 0.0213       |
# |    n_updates            | 172          |
# |    policy_gradient_loss | 0.00213      |
# |    value_loss           | 0.0883       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 830          |
# |    ep_rew_mean          | 1.9          |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 45           |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 0.0011072641 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0995       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.00152     |
# |    learning_rate        | 0.000249     |
# |    loss                 | 0.139        |
# |    n_updates            | 176          |
# |    policy_gradient_loss | 0.105        |
# |    value_loss           | 0.0581       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 830         |
# |    ep_rew_mean          | 1.89        |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 46          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.001249355 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.0995      |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00497     |
# |    learning_rate        | 0.000249    |
# |    loss                 | 0.0309      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00888    |
# |    value_loss           | 0.0833      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 825          |
# |    ep_rew_mean          | 1.85         |
# | time/                   |              |
# |    fps                  | 290          |
# |    iterations           | 47           |
# |    time_elapsed         | 165          |
# |    total_timesteps      | 48128        |
# | train/                  |              |
# |    approx_kl            | 0.0017382896 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0995       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.00372      |
# |    learning_rate        | 0.000249     |
# |    loss                 | 0.033        |
# |    n_updates            | 184          |
# |    policy_gradient_loss | 0.0058       |
# |    value_loss           | 0.0757       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 855         |
# |    ep_rew_mean          | 2.02        |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 48          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.002033973 |
# |    clip_fraction        | 0.0674      |
# |    clip_range           | 0.0995      |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.00471     |
# |    learning_rate        | 0.000249    |
# |    loss                 | 0.0202      |
# |    n_updates            | 188         |
# |    policy_gradient_loss | -0.0229     |
# |    value_loss           | 0.0808      |
# -----------------------------------------
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.2e+03       |
# |    mean_reward          | 5.4           |
# | time/                   |               |
# |    total_timesteps      | 50000         |
# | train/                  |               |
# |    approx_kl            | 0.00032620598 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.0995        |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0.0047        |
# |    learning_rate        | 0.000249      |
# |    loss                 | 0.00437       |
# |    n_updates            | 192           |
# |    policy_gradient_loss | -0.0205       |
# |    value_loss           | 0.0859        |
# -------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 852      |
# |    ep_rew_mean     | 2.01     |
# | time/              |          |
# |    fps             | 269      |
# |    iterations      | 49       |
# |    time_elapsed    | 185      |
# |    total_timesteps | 50176    |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 852           |
# |    ep_rew_mean          | 2.02          |
# | time/                   |               |
# |    fps                  | 271           |
# |    iterations           | 50            |
# |    time_elapsed         | 188           |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.00041563652 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.0995        |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.00417       |
# |    learning_rate        | 0.000249      |
# |    loss                 | 0.0195        |
# |    n_updates            | 196           |
# |    policy_gradient_loss | -0.00467      |
# |    value_loss           | 0.0829        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 864          |
# |    ep_rew_mean          | 2.09         |
# | time/                   |              |
# |    fps                  | 272          |
# |    iterations           | 51           |
# |    time_elapsed         | 191          |
# |    total_timesteps      | 52224        |
# | train/                  |              |
# |    approx_kl            | 0.0012018108 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0995       |
# ...
# |    iterations           | 67           |
# |    time_elapsed         | 245          |
# |    total_timesteps      | 68608        |
# | train/                  |              |
# |    approx_kl            | 0.0013365811 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0993       |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.00406      |
# |    learning_rate        | 0.000248     |
# |    loss                 | 0.0275       |
# |    n_updates            | 264          |
# |    policy_gradient_loss | 0.0111       |
# |    value_loss           | 0.0689       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 750           |
# |    ep_rew_mean          | 1.48          |
# | time/                   |               |
# |    fps                  | 280           |
# |    iterations           | 68            |
# |    time_elapsed         | 248           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 0.00075726816 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.0993        |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0.00145       |
# |    learning_rate        | 0.000248      |
# |    loss                 | 0.0432        |
# |    n_updates            | 268           |
# |    policy_gradient_loss | 0.0527        |
# |    value_loss           | 0.0557        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 750          |
# |    ep_rew_mean          | 1.46         |
# | time/                   |              |
# |    fps                  | 280          |
# |    iterations           | 69           |
# |    time_elapsed         | 252          |
# |    total_timesteps      | 70656        |
# | train/                  |              |
# |    approx_kl            | 0.0043209326 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.0993       |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.00818      |
# |    learning_rate        | 0.000248     |
# |    loss                 | -0.0473      |
# |    n_updates            | 272          |
# |    policy_gradient_loss | -0.0949      |
# |    value_loss           | 0.0981       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 738           |
# |    ep_rew_mean          | 1.36          |
# | time/                   |               |
# |    fps                  | 280           |
# |    iterations           | 70            |
# |    time_elapsed         | 255           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 0.00090930035 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.0993        |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | -0.00261      |
# |    learning_rate        | 0.000248      |
# |    loss                 | 0.0903        |
# |    n_updates            | 276           |
# |    policy_gradient_loss | 0.0849        |
# |    value_loss           | 0.0463        |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 748        |
# |    ep_rew_mean          | 1.43       |
# | time/                   |            |
# |    fps                  | 279        |
# |    iterations           | 71         |
# |    time_elapsed         | 259        |
# |    total_timesteps      | 72704      |
# | train/                  |            |
# |    approx_kl            | 0.00096406 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.0993     |
# |    entropy_loss         | -1.34      |
# |    explained_variance   | 0.00323    |
# |    learning_rate        | 0.000248   |
# |    loss                 | 0.0219     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | 0.0113     |
# |    value_loss           | 0.0626     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 737          |
# |    ep_rew_mean          | 1.32         |
# | time/                   |              |
# |    fps                  | 280          |
# |    iterations           | 72           |
# |    time_elapsed         | 262          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0006426032 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0993       |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.00298      |
# |    learning_rate        | 0.000248     |
# |    loss                 | 0.04         |
# |    n_updates            | 284          |
# |    policy_gradient_loss | 0.0164       |
# |    value_loss           | 0.0639       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 717          |
# |    ep_rew_mean          | 1.2          |
# | time/                   |              |
# |    fps                  | 281          |
# |    iterations           | 73           |
# |    time_elapsed         | 265          |
# |    total_timesteps      | 74752        |
# | train/                  |              |
# |    approx_kl            | 0.0014055371 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.0993       |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.00206      |
# |    learning_rate        | 0.000248     |
# |    loss                 | 0.0459       |
# |    n_updates            | 288          |
# |    policy_gradient_loss | 0.0324       |
# |    value_loss           | 0.0494       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 727          |
# |    ep_rew_mean          | 1.25         |
# | time/                   |              |
# |    fps                  | 282          |
# |    iterations           | 74           |
# |    time_elapsed         | 268          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0016417276 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.0993       |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.00474      |
# |    learning_rate        | 0.000248     |
# |    loss                 | 0.0237       |
# |    n_updates            | 292          |
# |    policy_gradient_loss | -0.0108      |
# |    value_loss           | 0.0693       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 717           |
# |    ep_rew_mean          | 1.2           |
# | time/                   |               |
# |    fps                  | 282           |
# |    iterations           | 75            |
# |    time_elapsed         | 271           |
# |    total_timesteps      | 76800         |
# | train/                  |               |
# |    approx_kl            | 0.00081775995 |
# |    clip_fraction        | 0.0283        |
# |    clip_range           | 0.0992        |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | 0.00613       |
# |    learning_rate        | 0.000248      |
# |    loss                 | -0.00978      |
# |    n_updates            | 296           |
# |    policy_gradient_loss | -0.0255       |
# |    value_loss           | 0.0668        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 715          |
# |    ep_rew_mean          | 1.2          |
# | time/                   |              |
# |    fps                  | 283          |
# |    iterations           | 76           |
# |    time_elapsed         | 274          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0015489185 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0992       |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.00699      |
# |    learning_rate        | 0.000248     |
# |    loss                 | -0.0548      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.0735      |
# |    value_loss           | 0.0879       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 724         |
# |    ep_rew_mean          | 1.25        |
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 77          |
# |    time_elapsed         | 278         |
# |    total_timesteps      | 78848       |
# | train/                  |             |
# |    approx_kl            | 0.001002209 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.0992      |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.00649     |
# |    learning_rate        | 0.000248    |
# |    loss                 | -0.0311     |
# |    n_updates            | 304         |
# |    policy_gradient_loss | -0.0546     |
# |    value_loss           | 0.0869      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 754          |
# |    ep_rew_mean          | 1.48         |
# | time/                   |              |
# |    fps                  | 283          |
# |    iterations           | 78           |
# |    time_elapsed         | 281          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0035783672 |
# |    clip_fraction        | 0.0823       |
# |    clip_range           | 0.0992       |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.00574      |
# |    learning_rate        | 0.000248     |
# |    loss                 | -0.0646      |
# |    n_updates            | 308          |
# |    policy_gradient_loss | -0.0833      |
# |    value_loss           | 0.101        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 758          |
# |    ep_rew_mean          | 1.5          |
# | time/                   |              |
# |    fps                  | 284          |
# |    iterations           | 79           |
# |    time_elapsed         | 284          |
# |    total_timesteps      | 80896        |
# | train/                  |              |
# |    approx_kl            | 0.0010979096 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0992       |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.00413      |
# |    learning_rate        | 0.000248     |
# |    loss                 | 0.0535       |
# |    n_updates            | 312          |
# |    policy_gradient_loss | -0.00248     |
# |    value_loss           | 0.09         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 765          |
# |    ep_rew_mean          | 1.59         |
# | time/                   |              |
# |    fps                  | 284          |
# |    iterations           | 80           |
# |    time_elapsed         | 287          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0014893815 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0992       |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.00511      |
# |    learning_rate        | 0.000248     |
# |    loss                 | 0.0124       |
# |    n_updates            | 316          |
# |    policy_gradient_loss | -0.00667     |
# |    value_loss           | 0.0951       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 766          |
# |    ep_rew_mean          | 1.6          |
# | time/                   |              |
# |    fps                  | 285          |
# |    iterations           | 81           |
# |    time_elapsed         | 290          |
# |    total_timesteps      | 82944        |
# | train/                  |              |
# |    approx_kl            | 0.0013538375 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0992       |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.0034       |
# |    learning_rate        | 0.000248     |
# |    loss                 | 0.0481       |
# |    n_updates            | 320          |
# |    policy_gradient_loss | 0.0284       |
# |    value_loss           | 0.0835       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 781          |
# |    ep_rew_mean          | 1.71         |
# | time/                   |              |
# |    fps                  | 286          |
# |    iterations           | 82           |
# |    time_elapsed         | 293          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0008247962 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.0992       |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.00594      |
# |    learning_rate        | 0.000248     |
# |    loss                 | 0.0617       |
# |    n_updates            | 324          |
# |    policy_gradient_loss | 0.0275       |
# |    value_loss           | 0.082        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 785          |
# |    ep_rew_mean          | 1.74         |
# | time/                   |              |
# |    fps                  | 284          |
# |    iterations           | 83           |
# |    time_elapsed         | 298          |
# |    total_timesteps      | 84992        |
# | train/                  |              |
# |    approx_kl            | 0.0030658415 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.0992       |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.00798      |
# |    learning_rate        | 0.000248     |
# |    loss                 | -0.0213      |
# |    n_updates            | 328          |
# |    policy_gradient_loss | -0.0373      |
# |    value_loss           | 0.0955       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 784         |
# |    ep_rew_mean          | 1.74        |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 84          |
# |    time_elapsed         | 301         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.004385624 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.0992      |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.00608     |
# |    learning_rate        | 0.000248    |
# |    loss                 | -0.0343     |
# |    n_updates            | 332         |
# |    policy_gradient_loss | -0.0598     |
# |    value_loss           | 0.1         |
# -----------------------------------------
